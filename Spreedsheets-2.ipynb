# %%
# Import pandas as pd
import pandas as pd

# Read the CSV and assign it to the variable data
data = pd.read_excel("fcc-new-coder-survey.xlsx")

# View the first few lines of data
data.head(5)
# Out:
#    FreeCodeCamp New Developer Survey Responses, 2016        Unnamed: 1  \
# 0  Source: https://www.kaggle.com/freecodecamp/20...               NaN
# 1                                                Age  AttendedBootcamp
# 2                                                 28                 0
# 3                                                 22                 0
# 4                                                 19                 0
#
#        Unnamed: 2         Unnamed: 3    Unnamed: 4         Unnamed: 5  \
# 0             NaN                NaN           NaN                NaN
# 1  BootcampFinish  BootcampLoanYesNo  BootcampName  BootcampRecommend
# 2             NaN                NaN           NaN                NaN
# 3             NaN                NaN           NaN                NaN
# 4             NaN                NaN           NaN                NaN
#
#        Unnamed: 6                     Unnamed: 7            Unnamed: 8  \
# ...

# %%
data.head(100)
# Out:
#     FreeCodeCamp New Developer Survey Responses, 2016        Unnamed: 1  \
# 0   Source: https://www.kaggle.com/freecodecamp/20...               NaN
# 1                                                 Age  AttendedBootcamp
# 2                                                  28                 0
# 3                                                  22                 0
# 4                                                  19                 0
# ..                                                ...               ...
# 95                                                 32                 1
# 96                                                 35                 0
# 97                                                 16                 0
# 98                                                 23                 0
# 99                                                 26                 1
#
#         Unnamed: 2         Unnamed: 3      Unnamed: 4         Unnamed: 5  \
# ...

# %%
# Create string of lettered columns to load
col_string = "AD, AW:BA"

# Load data with skiprows and usecols set
survey_responses = pd.read_excel("fcc-new-coder-survey.xlsx", 
                                 skiprows=2, 
                                 usecols=col_string)

# View the names of the columns selected
print(survey_responses.columns)
# Out:
# Index(['ExpectedEarning', 'JobApplyWhen', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobWherePref'],
#       dtype='object')

# %%
survey_responses.groupby("JobPref").count()
# Out:
#                                       ExpectedEarning  JobApplyWhen  \
# JobPref
# freelance                                           0             0
# start your own business                             0             0
# work for a medium-sized company                   219           239
# work for a multinational corporation               67            72
# work for a startup                                107           120
#
#                                       JobRelocateYesNo  JobRoleInterest  \
# JobPref
# freelance                                            0                0
# start your own business                              0                0
# work for a medium-sized company                    186              239
# work for a multinational corporation                55               71
# work for a startup                                  91              119
#
#                                       JobWherePref
# JobPref
# ...

# %%
survey_responses.head(5)
# Out:
#    ExpectedEarning              JobApplyWhen                          JobPref  \
# 0              NaN                       NaN                        freelance
# 1          50000.0  Within the next 6 months               work for a startup
# 2              NaN                       NaN          start your own business
# 3          65000.0  Within the next 6 months               work for a startup
# 4          45000.0  Within the next 6 months  work for a medium-sized company
#
#    JobRelocateYesNo           JobRoleInterest  \
# 0               NaN                       NaN
# 1               1.0   Front-End Web Developer
# 2               NaN                       NaN
# 3               NaN   Front-End Web Developer
# 4               1.0  Full-Stack Web Developer
#
#                          JobWherePref
# 0                                 NaN
# 1  in an office with other developers
# 2                                 NaN
# 3                           from home
# ...

# %% [markdown]
# Selecting all sheets adn append them into 1 data drame

# %%
#Reading Multiple sheets
sheets = pd.read_excel("fcc-new-coder-survey.xlsx",sheet_name=None)

# %%
sheets = pd.read_excel("fcc-new-coder-survey.xlsx",sheet_name=1)

# %%
# Create df from second worksheet by referencing its position
responses_2017 = pd.read_excel("fcc-new-coder-survey.xlsx",
                               sheet_name='2017')

# Graph where people would like to get a developer job
job_prefs = responses_2017.groupby("JobPref").JobPref.count()
job_prefs.plot.barh()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/d4/tmjldz113nxgms59zzgtjrnm0000gn/T/ipykernel_44715/1550412326.py in <module>
#       4
#       5 # Graph where people would like to get a developer job
# ----> 6 job_prefs = responses_2017.groupby("JobPref").JobPref.count()
#       7 job_prefs.plot.barh()
#       8 plt.show()
#
# ~/opt/anaconda3/envs/Python-Data/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# ...

# %%
# Load both the 2016 and 2017 sheets by name
all_survey_data = pd.read_excel("fcc-new-coder-survey.xlsx",
                                sheet_name=['2016', '2017'])

# View the data type of all_survey_data
print(type(all_survey_data))
# Out:
# <class 'dict'>

# %%
# Load all sheets in the Excel file
all_survey_data = pd.read_excel("fcc-new-coder-survey.xlsx",
                                sheet_name=[0,'2017'])

# View the sheet names in all_survey_data
print(all_survey_data.keys())
# Out:
# dict_keys([0, '2017'])

# %%
#Reading Multiple sheets
all_data = pd.read_excel("fcc-new-coder-survey.xlsx",sheet_name=None,skiprows=2)

# %%
combined_dataframe = pd.DataFrame()

for i in all_data.values():
     print("Adding {} rows".format(i.shape[0]))
     combined_dataframe = combined_dataframe.append(i)
#counts = combined_dataframe.groupby("EmploymentStatus").EmploymentStatus.count()     
combined_dataframe.head(1)
# Out:
# Adding 1000 rows
# Adding 1000 rows
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  28.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# 0                   NaN                   NaN  ...                  NaN
#
#    ResourceSkillCrush  ResourceStackOverflow  ResourceTreehouse  \
# 0                 NaN                    NaN                NaN
#
#    ResourceUdacity  ResourceUdemy  ResourceW3Schools  \
# 0              NaN            NaN                NaN
#
#                      SchoolDegree  SchoolMajor  StudentDebtOwe
# 0  some college credit, no degree          NaN           20000
#
# [1 rows x 98 columns]

# %%
# Out:
# 2016       FreeCodeCamp New Developer Survey Responses, 2016        Unnamed: 1  \
# 0     Source: https://www.kaggle.com/freecodecamp/20...               NaN
# 1                                                   Age  AttendedBootcamp
# 2                                                    28                 0
# 3                                                    22                 0
# 4                                                    19                 0
# ...                                                 ...               ...
# 997                                                  35                 0
# 998                                                  19                 0
# 999                                                  25                 0
# 1000                                                 28                 0
# 1001                                                 39                 0
#
#           Unnamed: 2         Unnamed: 3    Unnamed: 4         Unnamed: 5  \
# ...
